# %% [markdown]
# Create a Python code to generate similar output:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Seed for reproducibility
np.random.seed(0)

# Generate 60 random x values between 0 and 9
x = np.random.uniform(0, 9, 60)

# Generate 60 y values that are either 1 or 2, adding a small random offset to spread them vertically within their respective rows
y = np.random.choice([1, 2], 60) + np.random.normal(0, 0.1, 60)

# Define the figure with a specific size
plt.figure(figsize=(18, 12))

# Graph 1: Scatter plot of the joint distribution with points spread out
plt.subplot(2, 2, 1)
plt.scatter(x, y, alpha=0.7, c='blue', s=50)
plt.title('p(X, Y)')
plt.xlabel('X')
plt.ylim(0.5, 2.5)
plt.yticks([1, 2], ['Y = 1', 'Y = 2'])
plt.xlim(0, 9)
plt.xticks(np.arange(0, 10, 1),[])
plt.grid(which='major', color='red', linestyle='-', linewidth=2)
plt.hlines(1.5, 0, 9, colors='red', linestyles='-', linewidth=2) 
plt.grid(which='minor', color='red', linestyle='-', linewidth=2)
plt.gca().yaxis.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Graph 2: Horizontal bar graph for the fraction of Y values
plt.subplot(2, 2, 2)
plt.barh([1, 2], y_fractions, color='blue', alpha=0.7)
plt.title('p(Y)')
plt.xlim(0, 1)
plt.yticks([])
plt.xticks([])
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# Graph 3: Histogram for p(X)
plt.subplot(2, 2, 3)
plt.bar(x_values[:-1], hist_pX, color='blue', alpha=0.7)
plt.title('p(X)')
plt.xticks([])
plt.yticks([])

# Graph 4: Histogram for p(X|Y=1)
plt.subplot(2, 2, 4)
plt.bar(x_values[:-1], hist_pX_given_Y1, color='blue', alpha=0.7)
plt.title('p(X|Y = 1)')
plt.xticks([])
plt.yticks([])

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
